# %%
import sys; sys.argv = sys.argv + ["--run-date=2024-04-20"]
from association.modelling.fp_growth import main
# Out:
# [2024-05-16 16:20:08] {association:__init__.py:32} ERROR Could not import PySpark dbutils. Do not use ETL Modules:
#  No module named 'pyspark.dbutils'
# 24/05/16 16:20:10 WARN Utils: Your hostname, work resolves to a loopback address: 127.0.1.1; using 172.20.10.10 instead (on interface wlp0s20f3)
# 24/05/16 16:20:10 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 24/05/16 16:20:10 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# [2024-05-16 16:20:12] {warp.spark.io_adapters.delta.DeltaIOAdapter:delta.py:28} INFO Delta adapter is initialized.
# [2024-05-16 16:20:12] {warp.spark.io_adapters.parquet.ParquetIOAdapter:parquet.py:28} INFO Parquet adapter is initialized.

# %%
main()
# Out:
# [2024-05-16 16:20:12] {fp_growth:fp_growth.py:48} WARNING unknown arguments: ['-f', '/home/burhan/.local/share/jupyter/runtime/kernel-d8acbf5f-baeb-4cd8-9a0e-6baad9c44ced.json']
# [2024-05-16 16:20:12] {fp_growth:fp_growth.py:49} INFO arguments: Namespace(run_date='2024-04-20', min_support=0.01, min_confidence=0.01)
# [2024-05-16 16:20:12] {warp.core.logger.LoggerMixin:logger.py:868} INFO Starting: model function...
# [2024-05-16 16:20:12] {fp_growth:fp_growth.py:57} INFO Running fp_growth for 2024-04-20.
# [2024-05-16 16:20:12] {fp_growth:fp_growth.py:60} INFO Path suffix: run_date=2024-04-20.
# [2024-05-16 16:20:12] {warp.spark.io_adapters.parquet.ParquetIOAdapter:parquet.py:55} INFO Reading parquet data from /home/burhan/datastore/association/etl/transactional_sales_local
# 24/05/16 16:20:20 WARN RowBasedKeyValueBatch: Calling spill() on RowBasedKeyValueBatch. Will not spill but return 0.
# ...
